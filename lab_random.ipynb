# %% [markdown]
# <a href="https://colab.research.google.com/github/nathancdy/460-Lab-2/blob/main/lab_random.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # (IAT 460) Week 2 Lab — Part 1: Randomness and Chaos

# %% [markdown]
# ## 1. Lab Objectivess

# %% [markdown]
# In Week 1, we treated data as material and transformations as tools.
# This week, we introduce a new ingredient:
# **Uncertainty. Variation. Unpredictability.**
#
# Randomness is not the opposite of control. In computational creativity, randomness is often the source of diversity and richness.
#
# You are not expected to:
#
# - understand all the code
#
# - remember every function
#
# - optimize anything
#
# You are encouraged to:
#
# - observe
#
# - experiment
#
# - discuss
#
# - interpret
#
# This lab containes *non-graded* exercises for you to experiment with the notions we cover.

# %% [markdown]
# ## *Setup*

# %%
! pip install opensimplex matplotlib pillow numpy soundfile imageio noise tqdm
! mkdir outputs
# Out:
# Collecting opensimplex
#   Downloading opensimplex-0.4.5.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.13/dist-packages (3.10.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.13/dist-packages (11.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.13/dist-packages (2.1.3)
# Requirement already satisfied: soundfile in /usr/local/lib/python3.13/dist-packages (0.14.0)
# Requirement already satisfied: imageio in /usr/local/lib/python3.13/dist-packages (2.37.4)
# Collecting noise
#   Downloading noise-1.2.2.zip (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.0/132.0 kB 7.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tqdm in /usr/local/lib/python3.13/dist-packages (4.67.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.13/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib) (4.64.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib) (1.5.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib) (26.3)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.13/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.13/dist-packages (from soundfile) (2.1.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.13/dist-packages (from soundfile) (4.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.13/dist-packages (from cffi>=1.0->soundfile) (3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading opensimplex-0.4.5.1-py3-none-any.whl (267 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.0/268.0 kB 19.8 MB/s eta 0:00:00
# Building wheels for collected packages: noise
#   Building wheel for noise (setup.py) ... done
#   Created wheel for noise: filename=noise-1.2.2-cp313-cp313-linux_x86_64.whl size=57248 sha256=2d0be6c17880c987bc8169af9b58452f7b2cd9ea517a93cd1dcd14094ea1cb36
#   Stored in directory: /root/.cache/pip/wheels/6a/4c/99/fe9adf3dca70780d28cf2e24e63a11fee02bdbe5d9931d3c38
# Successfully built noise
# Installing collected packages: noise, opensimplex
# Successfully installed noise-1.2.2 opensimplex-0.4.5.1

# %% [markdown]
# ## 2. Randomness and Noise

# %% [markdown]
# ### 2.1 Imports and functions

# %%
import numpy as np
import matplotlib.pyplot as plt

from PIL import Image

# %% [markdown]
# This is a simple function to display a histogram based on a numpy array to show the distribution of sampled values

# %%
def plot_distribution(samples):
    count, bins, ignored = plt.hist(samples, 15, density=False)
    plt.hist(bins[:-1], bins)
    plt.show()

# %% [markdown]
# This function takes an array of pixels and then expands them to a given size, effectively creating a grid of colored squares

# %%
def assign_colors(samples, grid_size=(50,50,3), image_size=(512,512)):
    img = Image.fromarray(np.uint8(samples.reshape(grid_size)))
    return img.resize(image_size, Image.NEAREST)

# %%
# 50 squares by 50 squares with 3 channels for rgb
grid_size = (50, 50, 3)
n_samples = grid_size[0] * grid_size[1] * grid_size[2]

image_size = (512, 512)

# %% [markdown]
# ### 2.2 Probability distributions

# %% [markdown]
# #### Uniform Distribution
# - All values equally likely
# - Maximum unpredictability

# %%
samples = np.random.uniform(0, 255, n_samples)
plot_distribution(samples)
img = assign_colors(samples)
display(img)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %% [markdown]
# ### Uniform Distribution — Pure Chance
# - Values cluster around a mean
# - Controlled variation

# %%
samples = np.clip(np.random.normal(loc=128, scale=32, size=n_samples), 0, 255)
plot_distribution(samples)
img = assign_colors(samples)
display(img)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %% [markdown]
# #### Parameters to Explore
#
# - `loc` → brightness bias
#
# - `scale` → contrast / variation

# %% [markdown]
# ### Exponential Distribution — Rare Extremes
# - Many small values, few large ones
# - Long tail

# %%
samples = np.clip(np.random.exponential(scale=32, size=n_samples), 0, 255)
plot_distribution(samples)
img = assign_colors(samples)
display(img)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %% [markdown]
# ## 2.3 Noise Functions — Coherent Randomness
#
# Non-independant variables, noise depends on position.

# %% [markdown]
# #### Simplex / Perline Noise (2D)

# %%
from opensimplex import seed, noise2array

# %%
def simplex_grid(size, scale=4.0, seed_val=0):
    seed(seed_val)
    coords = np.linspace(0, scale, size[0])
    return noise2array(coords, coords)

# %%
# Define the grid of pixels and calculate the noise value at each coordinate
samples = np.zeros((50,50,3))
for c in range(3):
    samples[:,:,c] = simplex_grid((50,50), scale=4, seed_val=np.random.randint(1000))

# Display the result
samples = (samples / 2 + 0.5) * 255
img = assign_colors(samples.flatten())
display(img)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %% [markdown]
# ### Layered Noise

# %% [markdown]
# By layering noise at multiple scales, we get **complex structure**.

# %%
size = (256, 256)
samples = np.zeros(size)

# We add multiple noise values at different scales
samples += simplex_grid(size, scale=2, seed_val=1) * 1.0
samples += simplex_grid(size, scale=6, seed_val=2) * 0.5
samples += simplex_grid(size, scale=12, seed_val=3) * 0.25


samples = np.clip((samples / 2 + 0.5) * 255, 0, 255)
img = Image.fromarray(np.uint8(samples))
display(img)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %% [markdown]
# ## 2.4 Chaos: Deterministic but Unpredictable

# %% [markdown]
# #### Logistic Map (simple chaotic system)

# %%
# This function computes the logistic map sequence
def logistic_map(r, x0, n=100):
    x = x0
    values = []
    for _ in range(n):
        x = r * x * (1 - x)
        values.append(x)
    return values

# %%
values = logistic_map(r=3.9, x0=0.2)
plt.plot(values)
plt.title("Chaotic Time Series")
plt.show()

# %%
# We define multiple initial values
init_x0 = [0.2, 0.2000001, 0.199998]
n = 40

values = [
    logistic_map(r=3.9, x0=x0, n=n) for x0 in init_x0
]
# For each initial value sequence, we plot
for val in values:
    plt.plot(val, alpha=0.4)
plt.legend([f"x_0 = {x0}" for x0 in init_x0])
plt.title("Chaotic Time Series")
plt.show()

# %% [markdown]
# ## 2.5 Sound

# %% [markdown]
# ### 2.5.1 Audio Noise as Creative Material

# %% [markdown]
# #### *Setup*

# %%
import numpy as np
import soundfile as sf


sr = 44100 # sample rate
duration = 3.0 # seconds
n_samples = int(sr * duration)

# %% [markdown]
# #### White Noise

# %%
# Define white noise sequence
white = np.random.normal(0, 1, n_samples)
white /= np.max(np.abs(white))

# Save result
sf.write("outputs/white_noise.wav", white, sr)

# %%
from IPython.display import Audio

Audio(white, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## 2.6 Animating Noise

# %% [markdown]
# #### *Setup*

# %%
from noise import pnoise2, snoise2, pnoise3

plt.rcParams['figure.figsize'] = (6, 6)

# %% [markdown]
# #### Generate Animated Noise

# %% [markdown]
# We define the perlin noise functions

# %%
def perlin_noise_2d(width, height, scale=50):
    noise_img = np.zeros((height, width))
    for y in range(height):
        for x in range(width):
            noise_img[y, x] = pnoise2(x / scale, y / scale)
    return noise_img


noise_img = perlin_noise_2d(256, 256, scale=60)


plt.imshow(noise_img, cmap='gray')
plt.title("2D Perlin Noise")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(255.5), np.float64(255.5), np.float64(-0.5))

# %%
plt.imshow(noise_img, cmap='viridis')
plt.title("Perlin Noise with Color Map")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(255.5), np.float64(255.5), np.float64(-0.5))

# %% [markdown]
# The layered perlin noise function allows the add noise at multiple frequencies

# %%
def layered_perlin(width, height, scale=100, octaves=4, persistence=0.5, lacunarity=2.0):
    img = np.zeros((height, width))
    for y in range(height):
        for x in range(width):
            img[y, x] = pnoise2(
            x / scale,
            y / scale,
            octaves=octaves,
            persistence=persistence,
            lacunarity=lacunarity
            )
    return img


layered = layered_perlin(256, 256)


plt.imshow(layered, cmap='gray')
plt.title("Layered Perlin Noise")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(255.5), np.float64(255.5), np.float64(-0.5))

# %% [markdown]
# We define the simplex noise function

# %%
def simplex_noise_2d(width, height, scale=50):
    img = np.zeros((height, width))
    for y in range(height):
        for x in range(width):
            img[y, x] = snoise2(x / scale, y / scale)
    return img


simplex = simplex_noise_2d(256, 256, scale=60)


plt.imshow(simplex, cmap='gray')
plt.title("2D Simplex Noise")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(255.5), np.float64(255.5), np.float64(-0.5))

# %%
fig, axs = plt.subplots(1, 2, figsize=(10, 4))

# Plotting and comparing perlin noise and simplex noise

axs[0].imshow(noise_img, cmap='gray')
axs[0].set_title('Perlin')
axs[0].axis('off')


axs[1].imshow(simplex, cmap='gray')
axs[1].set_title('Simplex')
axs[1].axis('off')


plt.show()

# %% [markdown]
# ### Animating noise

# %%
from pathlib import Path
from tqdm import tqdm


width, height = 128, 128
scale = 40
frames = 120
speed = 0.1

# We compute noise images for each frame, while varying one parameter

frame_folder = Path("outputs/frames_noise")

imgs = []
for i in range(frames):
    t = i * speed
    img = np.zeros((height, width))
    for y in range(height):
        for x in range(width):
            img[y, x] = snoise2(x / scale, y / scale + t)
    imgs.append(img)

# %%
# Function to retrieve the computed images and create a video

def save_animation(imgs, frame_folder, video_fn = "noise_animation.mp4", fps = 30):

    frame_folder.mkdir(exist_ok=True)

    # save images into the frame folder
    for i, img in tqdm(enumerate(imgs), total=len(imgs)):
        fig = plt.figure(figsize=(6, 6))
        plt.imshow(img, cmap='viridis')


        # turn off axis ticks
        plt.xticks([])
        plt.yticks([])


        # save image
        plt.savefig(frame_folder / f'noise_{i:08d}.png', dpi=150)


        # close figure to avoid memory issues
        plt.close(fig)

    # change working directory to frame folder
    old_wd = Path.cwd()
    # %cd $frame_folder


    image_path_format = 'noise_%08d.png'


    # create video
    ! ffmpeg -r $fps -i $image_path_format -y $video_fn


    # return to original directory
    # %cd $old_wd

# %%
save_animation(imgs, frame_folder)
# Out:
# 100%|██████████| 120/120 [00:09<00:00, 12.04it/s]
# /content/outputs/frames_noise
# ffmpeg version 6.1.1-3ubuntu5 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13 (Ubuntu 13.2.0-23ubuntu3)
#   configuration: --prefix=/usr --extra-version=3ubuntu5 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --disable-omx --enable-gnutls --enable-libaom --enable-libass --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libglslang --enable-libgme --enable-libgsm --enable-libharfbuzz --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-openal --enable-opencl --enable-opengl --disable-sndio --enable-libvpl --disable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-ladspa --enable-libbluray --enable-libjack --enable-libpulse --enable-librabbitmq --enable-librist --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libx264 --enable-libzmq --enable-libzvbi --enable-lv2 --enable-sdl2 --enable-libplacebo --enable-librav1e --enable-pocketsphinx --enable-librsvg --enable-libjxl --enable-shared
#   libavutil      58. 29.100 / 58. 29.100
#   libavcodec     60. 31.102 / 60. 31.102
#   libavformat    60. 16.100 / 60. 16.100
#   libavdevice    60.  3.100 / 60.  3.100
#   libavfilter     9. 12.100 /  9. 12.100
#   libswscale      7.  5.100 /  7.  5.100
#   libswresample   4. 12.100 /  4. 12.100
#   libpostproc    57.  3.100 / 57.  3.100
# Input #0, image2, from 'noise_%08d.png':
#   Duration: 00:00:04.80, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: png, rgba(pc, gbr/unknown/unknown), 900x900 [SAR 5906:5906 DAR 1:1], 25 fps, 25 tbr, 25 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5ce46695e280] using SAR=1/1
# [libx264 @ 0x5ce46695e280] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x5ce46695e280] profile High 4:4:4 Predictive, level 3.1, 4:4:4, 8-bit
# [libx264 @ 0x5ce46695e280] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'noise_animation.mp4':
#   Metadata:
#     encoder         : Lavf60.16.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv444p(tv, progressive), 900x900 [SAR 1:1 DAR 1:1], q=2-31, 30 fps, 15360 tbn
#     Metadata:
#       encoder         : Lavc60.31.102 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# [out#0/mp4 @ 0x5ce46695c600] video:197kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.031721%
# frame=  120 fps= 23 q=-1.0 Lsize=     199kB time=00:00:03.90 bitrate= 417.6kbits/s speed=0.748x
# [libx264 @ 0x5ce46695e280] frame I:1     Avg QP:21.51  size: 14824
# [libx264 @ 0x5ce46695e280] frame P:38    Avg QP:23.36  size:  3489
# [libx264 @ 0x5ce46695e280] frame B:81    Avg QP:28.46  size:   659
# [libx264 @ 0x5ce46695e280] consecutive B-frames:  1.7%  0.0% 75.0% 23.3%
# [libx264 @ 0x5ce46695e280] mb I  I16..4: 34.2% 61.9%  3.9%
# [libx264 @ 0x5ce46695e280] mb P  I16..4:  4.5%  2.0%  0.3%  P16..4: 12.2%  3.8%  0.8%  0.0%  0.0%    skip:76.4%
# [libx264 @ 0x5ce46695e280] mb B  I16..4:  0.2%  0.0%  0.0%  B16..8: 16.7%  0.3%  0.0%  direct: 0.1%  skip:82.6%  L0:56.5% L1:43.3% BI: 0.2%
# [libx264 @ 0x5ce46695e280] 8x8 transform intra:37.1% inter:94.3%
# [libx264 @ 0x5ce46695e280] coded y,u,v intra: 20.6% 12.8% 15.2% inter: 1.1% 0.6% 0.6%
# [libx264 @ 0x5ce46695e280] i16 v,h,dc,p: 22% 41%  1% 36%
# [libx264 @ 0x5ce46695e280] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 31% 25% 36%  2%  1%  1%  1%  1%  1%
# [libx264 @ 0x5ce46695e280] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 47% 29% 21%  0%  0%  0%  0%  0%  0%
# [libx264 @ 0x5ce46695e280] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x5ce46695e280] ref P L0: 72.6%  6.9% 14.7%  5.8%
# [libx264 @ 0x5ce46695e280] ref B L0: 83.0% 15.8%  1.3%
# [libx264 @ 0x5ce46695e280] ref B L1: 95.6%  4.4%
# [libx264 @ 0x5ce46695e280] kb/s:401.64
# /content

# %%
# Defining 3D perlin noise gives us an extra dimension to traverse

def perlin_noise_3d(width, height, z, scale=50):
    img = np.zeros((height, width))
    for y in range(height):
        for x in range(width):
            img[y, x] = pnoise3(x / scale, y / scale, z)
    return img


perlin_3d = perlin_noise_3d(256, 256, 0, scale=60)


plt.imshow(perlin_3d, cmap='gray')
plt.title("3D Perlin Noise (2D Plane)")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(255.5), np.float64(255.5), np.float64(-0.5))

# %% [markdown]
# Here we show the similarity between two close `z` values.

# %%
fig, axs = plt.subplots(1, 2, figsize=(10, 4))

z_offset = 0.4

perlin_3d_close = perlin_noise_3d(256, 256, z_offset, scale=60)

axs[0].imshow(perlin_3d, cmap='gray')
axs[0].set_title('Perlin (z = 0.0)')
axs[0].axis('off')


axs[1].imshow(perlin_3d_close, cmap='gray')
axs[1].set_title('Perlin (z = 0.1)')
axs[1].axis('off')


plt.show()

# %% [markdown]
# By linearly varying our 3rd dimension (`z`), we create a video with interesting results.

# %%
width, height = 128, 128
scale = 40
frames = 120
speed = 0.1


frame_folder = Path("outputs/frames_perlin_3d")

imgs = []
for i in range(frames):
    t = i * speed
    img = np.zeros((height, width))
    for y in range(height):
        for x in range(width):
            img[y, x] = pnoise3(x / scale, y / scale, t*0.1)
    imgs.append(img)

save_animation(imgs, frame_folder)
# Out:
# 100%|██████████| 120/120 [00:10<00:00, 11.00it/s]
# /content/outputs/frames_perlin_3d
# ffmpeg version 6.1.1-3ubuntu5 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13 (Ubuntu 13.2.0-23ubuntu3)
#   configuration: --prefix=/usr --extra-version=3ubuntu5 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --disable-omx --enable-gnutls --enable-libaom --enable-libass --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libglslang --enable-libgme --enable-libgsm --enable-libharfbuzz --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-openal --enable-opencl --enable-opengl --disable-sndio --enable-libvpl --disable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-ladspa --enable-libbluray --enable-libjack --enable-libpulse --enable-librabbitmq --enable-librist --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libx264 --enable-libzmq --enable-libzvbi --enable-lv2 --enable-sdl2 --enable-libplacebo --enable-librav1e --enable-pocketsphinx --enable-librsvg --enable-libjxl --enable-shared
#   libavutil      58. 29.100 / 58. 29.100
#   libavcodec     60. 31.102 / 60. 31.102
#   libavformat    60. 16.100 / 60. 16.100
#   libavdevice    60.  3.100 / 60.  3.100
#   libavfilter     9. 12.100 /  9. 12.100
#   libswscale      7.  5.100 /  7.  5.100
#   libswresample   4. 12.100 /  4. 12.100
#   libpostproc    57.  3.100 / 57.  3.100
# Input #0, image2, from 'noise_%08d.png':
#   Duration: 00:00:04.80, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: png, rgba(pc, gbr/unknown/unknown), 900x900 [SAR 5906:5906 DAR 1:1], 25 fps, 25 tbr, 25 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x59e14bbfb280] using SAR=1/1
# [libx264 @ 0x59e14bbfb280] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x59e14bbfb280] profile High 4:4:4 Predictive, level 3.1, 4:4:4, 8-bit
# [libx264 @ 0x59e14bbfb280] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'noise_animation.mp4':
#   Metadata:
#     encoder         : Lavf60.16.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv444p(tv, progressive), 900x900 [SAR 1:1 DAR 1:1], q=2-31, 30 fps, 15360 tbn
#     Metadata:
#       encoder         : Lavc60.31.102 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# [out#0/mp4 @ 0x59e14bbf9600] video:151kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.498965%
# frame=  120 fps= 29 q=-1.0 Lsize=     153kB time=00:00:03.90 bitrate= 321.0kbits/s speed=0.934x
# [libx264 @ 0x59e14bbfb280] frame I:1     Avg QP:23.25  size:  5529
# [libx264 @ 0x59e14bbfb280] frame P:30    Avg QP:21.60  size:  3469
# [libx264 @ 0x59e14bbfb280] frame B:89    Avg QP:21.62  size:   493
# [libx264 @ 0x59e14bbfb280] consecutive B-frames:  0.8%  0.0%  2.5% 96.7%
# [libx264 @ 0x59e14bbfb280] mb I  I16..4: 45.9% 52.8%  1.3%
# [libx264 @ 0x59e14bbfb280] mb P  I16..4: 12.6%  4.1%  0.1%  P16..4: 22.7%  2.8%  0.2%  0.0%  0.0%    skip:57.5%
# [libx264 @ 0x59e14bbfb280] mb B  I16..4:  0.2%  0.0%  0.0%  B16..8: 12.4%  0.1%  0.0%  direct: 0.0%  skip:87.4%  L0:41.4% L1:57.9% BI: 0.6%
# [libx264 @ 0x59e14bbfb280] 8x8 transform intra:28.9% inter:99.5%
# [libx264 @ 0x59e14bbfb280] coded y,u,v intra: 3.9% 2.5% 3.0% inter: 0.6% 0.3% 0.4%
# [libx264 @ 0x59e14bbfb280] i16 v,h,dc,p: 20% 25%  3% 53%
# [libx264 @ 0x59e14bbfb280] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 34% 24% 39%  1%  1%  1%  1%  1%  0%
# [libx264 @ 0x59e14bbfb280] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 31% 28% 40%  0%  0%  0%  0%  0%  0%
# [libx264 @ 0x59e14bbfb280] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x59e14bbfb280] ref P L0: 67.6%  1.3% 17.5% 13.6%
# [libx264 @ 0x59e14bbfb280] ref B L0: 92.1%  6.5%  1.3%
# [libx264 @ 0x59e14bbfb280] ref B L1: 97.9%  2.1%
# [libx264 @ 0x59e14bbfb280] kb/s:306.97
# /content

# %% [markdown]
# We do the same for the layered perlin noise.

# %%
def layered_perlin_3d(width, height, z, scale=100, octaves=4, persistence=0.5, lacunarity=2.0):
    img = np.zeros((height, width))
    for y in range(height):
        for x in range(width):
            img[y, x] = pnoise3(
            x / scale,
            y / scale,
            z,
            octaves=octaves,
            persistence=persistence,
            lacunarity=lacunarity
            )
    return img

# %%
width, height = 128, 128
scale = 40
frames = 240
speed = 0.1

octaves=4
persistence=0.5
lacunarity=2.0

frame_folder = Path("outputs/frames_perlin_layered_3d")

imgs = []
for i in range(frames):
    t = i * speed
    img = np.zeros((height, width))
    for y in range(height):
        for x in range(width):
            img[y, x] = pnoise3(
                x / scale,
                y / scale,
                i * 0.1,
                octaves=octaves,
                persistence=persistence,
                lacunarity=lacunarity
            )
    imgs.append(img)

save_animation(imgs, frame_folder, video_fn="vid.mp4")
# Out:
# 100%|██████████| 240/240 [00:18<00:00, 12.65it/s]
# /content/outputs/frames_perlin_layered_3d
# ffmpeg version 6.1.1-3ubuntu5 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13 (Ubuntu 13.2.0-23ubuntu3)
#   configuration: --prefix=/usr --extra-version=3ubuntu5 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --disable-omx --enable-gnutls --enable-libaom --enable-libass --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libglslang --enable-libgme --enable-libgsm --enable-libharfbuzz --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-openal --enable-opencl --enable-opengl --disable-sndio --enable-libvpl --disable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-ladspa --enable-libbluray --enable-libjack --enable-libpulse --enable-librabbitmq --enable-librist --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libx264 --enable-libzmq --enable-libzvbi --enable-lv2 --enable-sdl2 --enable-libplacebo --enable-librav1e --enable-pocketsphinx --enable-librsvg --enable-libjxl --enable-shared
#   libavutil      58. 29.100 / 58. 29.100
#   libavcodec     60. 31.102 / 60. 31.102
#   libavformat    60. 16.100 / 60. 16.100
#   libavdevice    60.  3.100 / 60.  3.100
#   libavfilter     9. 12.100 /  9. 12.100
#   libswscale      7.  5.100 /  7.  5.100
#   libswresample   4. 12.100 /  4. 12.100
#   libpostproc    57.  3.100 / 57.  3.100
# Input #0, image2, from 'noise_%08d.png':
#   Duration: 00:00:09.60, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: png, rgba(pc, gbr/unknown/unknown), 900x900 [SAR 5906:5906 DAR 1:1], 25 fps, 25 tbr, 25 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x575689c19280] using SAR=1/1
# [libx264 @ 0x575689c19280] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x575689c19280] profile High 4:4:4 Predictive, level 3.1, 4:4:4, 8-bit
# [libx264 @ 0x575689c19280] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'vid.mp4':
#   Metadata:
#     encoder         : Lavf60.16.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv444p(tv, progressive), 900x900 [SAR 1:1 DAR 1:1], q=2-31, 30 fps, 15360 tbn
#     Metadata:
#       encoder         : Lavc60.31.102 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# [out#0/mp4 @ 0x575689c17600] video:1771kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.197104%
# frame=  240 fps= 14 q=-1.0 Lsize=    1775kB time=00:00:07.90 bitrate=1840.3kbits/s speed=0.474x
# [libx264 @ 0x575689c19280] frame I:7     Avg QP:22.74  size: 11421
# [libx264 @ 0x575689c19280] frame P:110   Avg QP:25.40  size:  7977
# [libx264 @ 0x575689c19280] frame B:123   Avg QP:26.31  size:  6956
# [libx264 @ 0x575689c19280] consecutive B-frames: 10.4% 55.8% 23.8% 10.0%
# [libx264 @ 0x575689c19280] mb I  I16..4: 27.4% 70.7%  1.9%
# [libx264 @ 0x575689c19280] mb P  I16..4: 19.8% 16.4%  0.2%  P16..4: 16.8%  5.2%  0.6%  0.0%  0.0%    skip:41.1%
# [libx264 @ 0x575689c19280] mb B  I16..4:  9.8%  8.7%  0.0%  B16..8: 27.4%  5.3%  0.3%  direct: 0.6%  skip:47.8%  L0:54.0% L1:43.3% BI: 2.7%
# [libx264 @ 0x575689c19280] 8x8 transform intra:48.2% inter:99.5%
# [libx264 @ 0x575689c19280] coded y,u,v intra: 17.0% 11.0% 12.8% inter: 7.6% 4.2% 5.8%
# [libx264 @ 0x575689c19280] i16 v,h,dc,p: 22% 23%  6% 49%
# [libx264 @ 0x575689c19280] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 31% 24% 30%  3%  2%  2%  2%  3%  2%
# [libx264 @ 0x575689c19280] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 35% 24% 37%  0%  1%  1%  1%  0%  0%
# [libx264 @ 0x575689c19280] Weighted P-Frames: Y:0.9% UV:0.0%
# [libx264 @ 0x575689c19280] ref P L0: 52.4%  3.5% 25.8% 18.2%  0.1%
# [libx264 @ 0x575689c19280] ref B L0: 72.5% 24.4%  3.2%
# [libx264 @ 0x575689c19280] ref B L1: 98.6%  1.4%
# [libx264 @ 0x575689c19280] kb/s:1813.07
# /content
